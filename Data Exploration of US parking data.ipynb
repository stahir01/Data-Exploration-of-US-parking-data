# %% [markdown]
# # Analyzing US parking data

# %% [markdown]
# In this case study, we will analyze US parkking space data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
parking_data = pd.read_excel('parking.xls')

# %%
parking_data
# Out:
#         Bldg City Bldg State Bldg Status Property Type  Total Parking Spaces  \
# 0        HARTFORD         CT      ACTIVE      BUILDING                    29
# 1       NEW HAVEN         CT      ACTIVE      BUILDING                     0
# 2       WATERBURY         CT      ACTIVE      BUILDING                     2
# 3     WILLIMANTIC         CT      ACTIVE      BUILDING                     0
# 4        HARTFORD         CT      ACTIVE      BUILDING                   103
# ...           ...        ...         ...           ...                   ...
# 9055       FALLON         NV      ACTIVE      BUILDING                    12
# 9056         ELKO         NV      ACTIVE      BUILDING                     2
# 9057    LAS VEGAS         NV      ACTIVE      BUILDING                     3
# 9058    LAS VEGAS         NV      ACTIVE      BUILDING                    24
# 9059    LAS VEGAS         NV      ACTIVE      BUILDING                     7
#
#      Owned/Leased
# 0           OWNED
# ...

# %%
parking_data.head()
# Out:
#      Bldg City Bldg State Bldg Status Property Type  Total Parking Spaces  \
# 0     HARTFORD         CT      ACTIVE      BUILDING                    29
# 1    NEW HAVEN         CT      ACTIVE      BUILDING                     0
# 2    WATERBURY         CT      ACTIVE      BUILDING                     2
# 3  WILLIMANTIC         CT      ACTIVE      BUILDING                     0
# 4     HARTFORD         CT      ACTIVE      BUILDING                   103
#
#   Owned/Leased
# 0        OWNED
# 1        OWNED
# 2       LEASED
# 3       LEASED
# 4        OWNED

# %%
parking_data.tail()
# Out:
#       Bldg City Bldg State Bldg Status Property Type  Total Parking Spaces  \
# 9055     FALLON         NV      ACTIVE      BUILDING                    12
# 9056       ELKO         NV      ACTIVE      BUILDING                     2
# 9057  LAS VEGAS         NV      ACTIVE      BUILDING                     3
# 9058  LAS VEGAS         NV      ACTIVE      BUILDING                    24
# 9059  LAS VEGAS         NV      ACTIVE      BUILDING                     7
#
#      Owned/Leased
# 9055       LEASED
# 9056       LEASED
# 9057       LEASED
# 9058       LEASED
# 9059       LEASED

# %%
Bldg_status_unqiue = parking_data['Bldg Status'].unique()
print('The unique Building status are:' + str(Bldg_status_unqiue ))
# Out:
# The unique Building status are:['ACTIVE' 'DECOMMISSIONED' 'EXCESS']

# %%
Bldg_City_unqiue = parking_data['Bldg City'].unique()
Bldg_State_unique = parking_data['Bldg State'].unique()
Property_type_unique = parking_data['Property Type'].unique()
print('The unique city building are:' + str(Bldg_City_unqiue) + '\n'+'The unqiue State buildings are:' + str(Bldg_State_unique) + '\n'  + 
      'The different type of properties are:' + str(Property_type_unique))
# Out:
# The unique city building are:['HARTFORD' 'NEW HAVEN' 'WATERBURY' ... 'STATELINE' 'PAHRUMP' 'FALLON']
# The unqiue State buildings are:['CT' 'MA' 'ME' 'NH' 'RI' 'VT' 'ID' 'OR' 'WA' 'DC' 'MD' 'VA' 'NJ' 'NY'
#  'DE' 'PA' 'WV' 'AL' 'FL' 'GA' 'KY' 'MS' 'NC' 'SC' 'TN' 'IL' 'IN' 'MI'
#  'MN' 'OH' 'WI' 'IA' 'KS' 'MO' 'NE' 'AR' 'LA' 'NM' 'OK' 'TX' 'CO' 'MT'
#  'ND' 'SD' 'UT' 'WY' 'AZ' 'CA' 'NV']
# The different type of properties are:['BUILDING' 'STRUCTURE' 'LAND']

# %% [markdown]
# We will check how many Total Parking Spaces	 are owned/leased and what are those building status

# %%
plt.bar(parking_data['Owned/Leased'], parking_data['Total Parking Spaces'])
plt.xlabel('Owned/Leased')
plt.ylabel('Total Parking Space')
# Out:
# Text(0, 0.5, 'Total Parking Space')

# %% [markdown]
# ## In which building was the parking space in excess?

# %%
excess_parking = pd.pivot_table(parking_data, index= 'Bldg State', columns= 'Bldg Status', values = 'Total Parking Spaces')
excess_parking
# Out:
# Bldg Status      ACTIVE  DECOMMISSIONED      EXCESS
# Bldg State
# AL            62.357724             NaN   59.000000
# AR            37.000000             NaN         NaN
# AZ            32.256757             NaN         NaN
# CA            60.493298             NaN         NaN
# CO            78.936709             NaN   22.200000
# CT            29.327586             NaN         NaN
# DC            41.255144             NaN         NaN
# DE            15.750000             NaN         NaN
# FL            51.905569             NaN         NaN
# GA            76.408257             NaN         NaN
# IA            27.202703             NaN         NaN
# ID            39.274194        0.000000         NaN
# IL            45.000000             NaN   21.000000
# IN            44.069444             NaN    0.000000
# KS            55.216216             NaN         NaN
# KY            46.277372             NaN         NaN
# LA            43.684932             NaN   68.666667
# ...

# %%
excess_parking = excess_parking[excess_parking['EXCESS'] > 0]
excess_parking
# Out:
# Bldg Status      ACTIVE  DECOMMISSIONED      EXCESS
# Bldg State
# AL            62.357724             NaN   59.000000
# CO            78.936709             NaN   22.200000
# IL            45.000000             NaN   21.000000
# LA            43.684932             NaN   68.666667
# MD           104.185090        0.000000   43.166667
# MO           121.200000      815.333333  254.272727
# NE            54.060000             NaN   19.000000
# NJ            32.169118             NaN    4.300000
# NV            48.648649             NaN  173.000000
# OK            39.108527             NaN   14.000000
# WI            23.247934             NaN   22.000000

# %%
excess_parking_2 = excess_parking.drop(columns=['ACTIVE', 'DECOMMISSIONED'])
excess_parking_2
# Out:
# Bldg Status      EXCESS
# Bldg State
# AL            59.000000
# CO            22.200000
# IL            21.000000
# LA            68.666667
# MD            43.166667
# MO           254.272727
# NE            19.000000
# NJ             4.300000
# NV           173.000000
# OK            14.000000
# WI            22.000000

# %%
excess_parking_2.plot(kind='bar')
plt.ylabel('Amount in Excess')
# Out:
# Text(0, 0.5, 'Amount in Excess')

# %%
excess_parking_2 = excess_parking_2.sort_values('EXCESS', ascending=False)
excess_parking_2.plot(kind='bar')
plt.ylabel('Amount in Excess')
# Out:
# Text(0, 0.5, 'Amount in Excess')

# %% [markdown]
# ## Which building cities have been decommissioned with their parking space

# %%
parking_data
# Out:
#         Bldg City Bldg State Bldg Status Property Type  Total Parking Spaces  \
# 0        HARTFORD         CT      ACTIVE      BUILDING                    29
# 1       NEW HAVEN         CT      ACTIVE      BUILDING                     0
# 2       WATERBURY         CT      ACTIVE      BUILDING                     2
# 3     WILLIMANTIC         CT      ACTIVE      BUILDING                     0
# 4        HARTFORD         CT      ACTIVE      BUILDING                   103
# ...           ...        ...         ...           ...                   ...
# 9055       FALLON         NV      ACTIVE      BUILDING                    12
# 9056         ELKO         NV      ACTIVE      BUILDING                     2
# 9057    LAS VEGAS         NV      ACTIVE      BUILDING                     3
# 9058    LAS VEGAS         NV      ACTIVE      BUILDING                    24
# 9059    LAS VEGAS         NV      ACTIVE      BUILDING                     7
#
#      Owned/Leased
# 0           OWNED
# ...

# %%
Bldg_cities_Dec = parking_data.drop(columns=['Bldg State', 'Property Type', 'Owned/Leased'])
Bldg_cities_Dec
# Out:
#         Bldg City Bldg Status  Total Parking Spaces
# 0        HARTFORD      ACTIVE                    29
# 1       NEW HAVEN      ACTIVE                     0
# 2       WATERBURY      ACTIVE                     2
# 3     WILLIMANTIC      ACTIVE                     0
# 4        HARTFORD      ACTIVE                   103
# ...           ...         ...                   ...
# 9055       FALLON      ACTIVE                    12
# 9056         ELKO      ACTIVE                     2
# 9057    LAS VEGAS      ACTIVE                     3
# 9058    LAS VEGAS      ACTIVE                    24
# 9059    LAS VEGAS      ACTIVE                     7
#
# [9060 rows x 3 columns]

# %%
Bldg_cities_Dec = Bldg_cities_Dec[(Bldg_cities_Dec['Bldg Status']  == 'DECOMMISSIONED')  & (Bldg_cities_Dec['Total Parking Spaces'] > 0)]
Bldg_cities_Dec
# Out:
#         Bldg City     Bldg Status  Total Parking Spaces
# 5716     OVERLAND  DECOMMISSIONED                  2089
# 5725  SAINT LOUIS  DECOMMISSIONED                   357

# %% [markdown]
# ## In which type of property is parking space in excess

# %%
prop_park_excess = parking_data.drop(columns = ['Bldg City', 'Bldg State', 'Owned/Leased'])
prop_park_excess =pd.pivot_table(prop_park_excess[prop_park_excess['Bldg Status'] == 'EXCESS'], index= 'Property Type',values = 'Total Parking Spaces')
prop_park_excess
# Out:
#                Total Parking Spaces
# Property Type
# BUILDING                  57.791045
# STRUCTURE                 37.000000

# %% [markdown]
# # States with more leased parking

# %%
states_leased_parking = pd.pivot_table(parking_data[parking_data['Owned/Leased'] == 'LEASED'], index='Bldg State', values = 'Total Parking Spaces')
states_leased_parking = states_leased_parking.sort_values('Total Parking Spaces', ascending=False)
states_leased_parking.head()
# Out:
#             Total Parking Spaces
# Bldg State
# MO                    107.762821
# TX                     73.457086
# VA                     72.476316
# AL                     64.055556
# UT                     62.505882

# %% [markdown]
# ## States which have Maximum and Minimum parking space

# %%
import numpy as np
max_min_space = pd.pivot_table(parking_data, index = 'Bldg State', values = 'Total Parking Spaces')
max_min_space = max_min_space.sort_values('Total Parking Spaces', ascending=False)
print('The parking space is: \n' + str(max_min_space.head(1)) + '\n' + 'The minimum parking space is \n' +
str(max_min_space.tail(1)))
# Out:
# The parking space is:
#             Total Parking Spaces
# Bldg State
# MO                    138.167464
# The minimum parking space is
#             Total Parking Spaces
# Bldg State
# ND                        13.475
